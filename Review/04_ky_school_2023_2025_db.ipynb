# %% [markdown]
# # Kentucky School Initial Data Review
#
# Investigate Kentucky public school education data to explore the relationship between student enrollment, chronic absenteeism, and dropout rate.

# %% [markdown]
# Libraries and Parameters

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
import seaborn as sns
import matplotlib.ticker as mticker

# %% [markdown]
# ## KY School Data (2023-2025)

# %%
enrollment_2023_2024_df = pd.read_csv("../Dataset/KYRC24_OVW_Student_Enrollment.csv",  dtype={'NCES ID': 'string'}, na_values=['NaN'])
enrollment_2024_2025_df = pd.read_csv("../Dataset/KYRC25_OVW_Student_Enrollment.csv",  dtype={'NCES ID': 'string'}, na_values=['NaN'])

absenteeism_2023_2024_df = pd.read_csv("../Dataset/KYRC24_OVW_Chronic_Absenteeism.csv",  dtype={'NCES ID': 'string'}, na_values=['NaN'])
absenteeism_2024_2025_df = pd.read_csv("../Dataset/KYRC25_OVW_Chronic_Absenteeism.csv",  dtype={'NCES ID': 'string'}, na_values=['NaN'])

dropout_2023_2024_df = pd.read_csv("../Dataset/KYRC24_OVW_Dropout_Rate.csv",  dtype={'NCES ID': 'string'}, na_values=['NaN'])
dropout_2024_2025_df = pd.read_csv("../Dataset/KYRC25_OVW_Dropout_Rate.csv",  dtype={'NCES ID': 'string'}, na_values=['NaN'])

regions_df = pd.read_csv("../Dataset/Ky_County_Polygons_WM.csv")

enrollment_df = pd.concat([enrollment_2023_2024_df, enrollment_2024_2025_df], ignore_index=True)
chronic_absenteeism_df = pd.concat([absenteeism_2023_2024_df, absenteeism_2024_2025_df], ignore_index=True)
dropout_rate_df = pd.concat([dropout_2023_2024_df, dropout_2024_2025_df], ignore_index=True)

# %% [markdown]
# ## Initial Dataset Review

# %%
regions_df
# Out:
#      OBJECTID      NAME  FIPS_ID     NAME2            ADDNAME          SEAT  \
# 0           1     ADAIR    21001     Adair    LAKE CUMBERLAND      Columbia
# 1           2     ALLEN    21003     Allen       BARREN RIVER   Scottsville
# 2           3  ANDERSON    21005  Anderson          BLUEGRASS  Lawrenceburg
# 3           4   BALLARD    21007   Ballard           PURCHASE     Wickliffe
# 4           5    BARREN    21009    Barren       BARREN RIVER       Glasgow
# ..        ...       ...      ...       ...                ...           ...
# 115       116     WAYNE    21231     Wayne    LAKE CUMBERLAND    Monticello
# 116       117   WEBSTER    21233   Webster        GREEN RIVER         Dixon
# 117       118   WHITLEY    21235   Whitley  CUMBERLAND VALLEY  Williamsburg
# 118       119     WOLFE    21237     Wolfe     KENTUCKY RIVER       Campton
# 119       120  WOODFORD    21239  Woodford          BLUEGRASS    Versailles
#
#             SEAT2  FORM_YR                           PARENTCO  FIPS_NO  ...  \
# 0        COLUMBIA     1802                              Green        1  ...
# 1     SCOTTSVILLE     1815                     Barren, Warren        3  ...
# 2    LAWRENCEBURG     1827       Franklin, Mercer, Washington        5  ...
# 3       WICKLIFFE     1842                 Hickman, McCracken        7  ...
# 4         GLASGOW     1799                      Green, Warren        9  ...
# ..            ...      ...                                ...      ...  ...
# 115    MONTICELLO     1801                Cumberland, Pulaski      231  ...
# 116         DIXON     1860          Henderson, Hopkins, Union      233  ...
# 117  WILLIAMSBURG     1818                               Knox      235  ...
# 118       CAMPTON     1860  Breathitt, Morgan, Owsley, Powell      237  ...
# 119    VERSAILLES     1789                            Fayette      239  ...
#
#                                                CONTACT       LAST_UPDT  \
# 0    TRANSPORTATION SYSTEMS BRANCH MANAGER, DIVISIO...   7/1/1993 0:00
# 1    TRANSPORTATION SYSTEMS BRANCH MANAGER, DIVISIO...   7/1/1993 0:00
# 2    TRANSPORTATION SYSTEMS BRANCH MANAGER, DIVISIO...   7/1/1993 0:00
# 3                                           KIM ANNESS  7/23/2015 0:00
# 4    TRANSPORTATION SYSTEMS BRANCH MANAGER, DIVISIO...   7/1/1993 0:00
# ..                                                 ...             ...
# 115  TRANSPORTATION SYSTEMS BRANCH MANAGER, DIVISIO...   7/1/1993 0:00
# 116  TRANSPORTATION SYSTEMS BRANCH MANAGER, DIVISIO...   7/1/1993 0:00
# 117  TRANSPORTATION SYSTEMS BRANCH MANAGER, DIVISIO...   7/1/1993 0:00
# 118  TRANSPORTATION SYSTEMS BRANCH MANAGER, DIVISIO...   7/1/1993 0:00
# 119  TRANSPORTATION SYSTEMS BRANCH MANAGER, DIVISIO...   7/1/1993 0:00
#
#                                              XY_SOURCE XY_ISSUES  \
# 0    BOUNDARY DIGITIZED FROM USGS 7.5 MINUTE TOPOGR...       NaN
# 1    BOUNDARY DIGITIZED FROM USGS 7.5 MINUTE TOPOGR...       NaN
# 2    BOUNDARY DIGITIZED FROM USGS 7.5 MINUTE TOPOGR...       NaN
# 3                OHIO V. KENTUCKY, 444 U.S. 335 (1980)       NaN
# 4    BOUNDARY DIGITIZED FROM USGS 7.5 MINUTE TOPOGR...       NaN
# ..                                                 ...       ...
# 115  BOUNDARY DIGITIZED FROM USGS 7.5 MINUTE TOPOGR...       NaN
# 116  BOUNDARY DIGITIZED FROM USGS 7.5 MINUTE TOPOGR...       NaN
# 117  BOUNDARY DIGITIZED FROM USGS 7.5 MINUTE TOPOGR...       NaN
# 118  BOUNDARY DIGITIZED FROM USGS 7.5 MINUTE TOPOGR...       NaN
# 119  BOUNDARY DIGITIZED FROM USGS 7.5 MINUTE TOPOGR...       NaN
#
#              ATT_SOURCE  ATT_ISSUES  \
# 0    SECRETARY OF STATE         NaN
# 1    SECRETARY OF STATE         NaN
# 2    SECRETARY OF STATE         NaN
# 3    SECRETARY OF STATE         NaN
# 4    SECRETARY OF STATE         NaN
# ..                  ...         ...
# 115  SECRETARY OF STATE         NaN
# 116  SECRETARY OF STATE         NaN
# 117  SECRETARY OF STATE         NaN
# 118  SECRETARY OF STATE         NaN
# 119  SECRETARY OF STATE         NaN
#
#                                               COMMENTS  KYTC_District_Num  \
# 0                                                  NaN                  8
# 1                                                  NaN                  3
# 2                                                  NaN                  7
# 3    BOUNDARY UPDATED TO MATCH SUPREME COURT CASE R...                  1
# 4                                                  NaN                  3
# ..                                                 ...                ...
# 115                                                NaN                  8
# 116                                                NaN                  2
# 117                                                NaN                 11
# 118                                                NaN                 10
# 119                                                NaN                  7
#
#       Shape__Area  Shape__Length
# 0    1.682320e+09    176916.9036
# 1    1.422340e+09    212158.8170
# 2    8.534822e+08    187271.1613
# 3    1.116332e+09    169743.5539
# 4    2.032351e+09    235199.6736
# ..            ...            ...
# 115  1.959573e+09    214715.8624
# 116  1.384222e+09    197143.2294
# 117  1.799520e+09    238465.4839
# 118  9.241010e+08    184878.7025
# 119  8.032135e+08    187168.7892
#
# [120 rows x 47 columns]

# %%
enrollment_df
# Out:
#        School Year  County Number County Name  District Number  District Name  \
# 0         20232024            NaN         NaN              999  All Districts
# 1         20232024            NaN         NaN              999  All Districts
# 2         20232024            NaN         NaN              999  All Districts
# 3         20232024            NaN         NaN              999  All Districts
# 4         20232024            NaN         NaN              999  All Districts
# ...            ...            ...         ...              ...            ...
# 46223     20242025          106.0      SHELBY              531  Shelby County
# 46224     20242025          106.0      SHELBY              531  Shelby County
# 46225     20242025          106.0      SHELBY              531  Shelby County
# 46226     20242025          106.0      SHELBY              531  Shelby County
# 46227     20242025          106.0      SHELBY              531  Shelby County
#
#        School Number                         School Name  School Code  \
# 0                NaN                         All Schools       999000
# 1                NaN                         All Schools       999000
# 2                NaN                         All Schools       999000
# 3                NaN                         All Schools       999000
# 4                NaN                         All Schools       999000
# ...              ...                                 ...          ...
# 46223           25.0  Cultivate Virtual Learning Academy       531025
# 46224           25.0  Cultivate Virtual Learning Academy       531025
# 46225           25.0  Cultivate Virtual Learning Academy       531025
# 46226           25.0  Cultivate Virtual Learning Academy       531025
# 46227           25.0  Cultivate Virtual Learning Academy       531025
#
#        State School Id       NCES ID  ... Grade 4  Grade 5 Grade 6 Grade 7  \
# 0                  NaN          <NA>  ...  49,321   49,728  46,144  49,278
# 1                  NaN          <NA>  ...  23,912   24,119  22,146  23,926
# 2                  NaN          <NA>  ...  25,409   25,609  23,998  25,352
# 3                  NaN          <NA>  ...   5,279    5,381   4,763   5,474
# 4                  NaN          <NA>  ...      84       68      59      59
# ...                ...           ...  ...     ...      ...     ...     ...
# 46223      106531025.0  210532000000  ...     NaN      NaN       0       0
# 46224      106531025.0  210532000000  ...     NaN      NaN       0       0
# 46225      106531025.0  210532000000  ...     NaN      NaN       1       1
# 46226      106531025.0  210532000000  ...     NaN      NaN       0       0
# 46227      106531025.0  210532000000  ...     NaN      NaN       0       0
#
#       Grade 8 Grade 9 Grade 10 Grade 11 Grade 12 Grade 14
# 0      50,090  56,075   54,149   50,192   47,786    653.0
# 1      24,063  27,061   26,353   24,607   23,210    217.0
# 2      26,027  29,014   27,796   25,585   24,576    436.0
# 3       5,541   6,605    6,294    5,566    5,059    103.0
# 4          72      79       66       78       68      0.0
# ...       ...     ...      ...      ...      ...      ...
# 46223       0       1        3        6       11      NaN
# 46224       0       1        0        2        0      NaN
# 46225       0       0        3        2        4      NaN
# 46226       0       0        1        1        0      NaN
# 46227       0       0        0        1        0      NaN
#
# [46228 rows x 30 columns]

# %%
chronic_absenteeism_df
# Out:
#         School Year  County Number County Name  District Number  \
# 0          20232024            NaN         NaN              999
# 1          20232024            NaN         NaN              999
# 2          20232024            NaN         NaN              999
# 3          20232024            NaN         NaN              999
# 4          20232024            NaN         NaN              999
# ...             ...            ...         ...              ...
# 543271     20242025           73.0     MADISON              606
# 543272     20242025           73.0     MADISON              606
# 543273     20242025           73.0     MADISON              606
# 543274     20242025           73.0     MADISON              606
# 543275     20242025           73.0     MADISON              606
#
#                           District Name  School Number        School Name  \
# 0                         All Districts            NaN        All Schools
# 1                         All Districts            NaN        All Schools
# 2                         All Districts            NaN        All Schools
# 3                         All Districts            NaN        All Schools
# 4                         All Districts            NaN        All Schools
# ...                                 ...            ...                ...
# 543271  Model Laboratory Schools at EKU          460.0  Model High School
# 543272  Model Laboratory Schools at EKU          460.0  Model High School
# 543273  Model Laboratory Schools at EKU          460.0  Model High School
# 543274  Model Laboratory Schools at EKU          460.0  Model High School
# 543275  Model Laboratory Schools at EKU          460.0  Model High School
#
#         School Code  State School Id      NCES ID CO-OP  CO-OP Code  \
# 0            999000              NaN         <NA>   NaN         NaN
# 1            999000              NaN         <NA>   NaN         NaN
# 2            999000              NaN         <NA>   NaN         NaN
# 3            999000              NaN         <NA>   NaN         NaN
# 4            999000              NaN         <NA>   NaN         NaN
# ...             ...              ...          ...   ...         ...
# 543271       606460       73606460.0  2.10029E+11   NaN         NaN
# 543272       606460       73606460.0  2.10029E+11   NaN         NaN
# 543273       606460       73606460.0  2.10029E+11   NaN         NaN
# 543274       606460       73606460.0  2.10029E+11   NaN         NaN
# 543275       606460       73606460.0  2.10029E+11   NaN         NaN
#
#        School Type       Grade                       Demographic Suppressed  \
# 0              NaN  All Grades                      All Students         No
# 1              NaN  All Grades                            Female         No
# 2              NaN  All Grades                              Male         No
# 3              NaN  All Grades                  African American         No
# 4              NaN  All Grades  American Indian or Alaska Native         No
# ...            ...         ...                               ...        ...
# 543271          B1        14th                       Foster Care        Yes
# 543272          B1        14th               Gifted and Talented        Yes
# 543273          B1        14th                          Homeless        Yes
# 543274          B1        14th                           Migrant        Yes
# 543275          B1        14th                Military Dependent        Yes
#
#        Chronically Absent Students Students Enrolled 10 or More Days  \
# 0                          186,415                           664,910
# 1                           91,571                           321,064
# 2                           94,844                           343,846
# 3                           25,283                            73,438
# 4                              290                               962
# ...                            ...                               ...
# 543271                           *                                 *
# 543272                           *                                 *
# 543273                           *                                 *
# 543274                           *                                 *
# 543275                           *                                 *
#
#        Chronic Absenteeism Rate
# 0                            28
# 1                          28.5
# 2                          27.6
# 3                          34.4
# 4                          30.1
# ...                         ...
# 543271                        *
# 543272                        *
# 543273                        *
# 543274                        *
# 543275                        *
#
# [543276 rows x 19 columns]

# %%
dropout_rate_df
# Out:
#        School Year  County Number County Name  District Number  \
# 0         20232024            NaN         NaN              999
# 1         20232024            NaN         NaN              999
# 2         20232024            NaN         NaN              999
# 3         20232024            NaN         NaN              999
# 4         20232024            NaN         NaN              999
# ...            ...            ...         ...              ...
# 24529     20242025           73.0     MADISON              606
# 24530     20242025           73.0     MADISON              606
# 24531     20242025           73.0     MADISON              606
# 24532     20242025           73.0     MADISON              606
# 24533     20242025           73.0     MADISON              606
#
#                          District Name  School Number        School Name  \
# 0                        All Districts            NaN        All Schools
# 1                        All Districts            NaN        All Schools
# 2                        All Districts            NaN        All Schools
# 3                        All Districts            NaN        All Schools
# 4                        All Districts            NaN        All Schools
# ...                                ...            ...                ...
# 24529  Model Laboratory Schools at EKU          460.0  Model High School
# 24530  Model Laboratory Schools at EKU          460.0  Model High School
# 24531  Model Laboratory Schools at EKU          460.0  Model High School
# 24532  Model Laboratory Schools at EKU          460.0  Model High School
# 24533  Model Laboratory Schools at EKU          460.0  Model High School
#
#        School Code  State School Id      NCES ID CO-OP  CO-OP Code  \
# 0           999000              NaN         <NA>   NaN         NaN
# 1           999000              NaN         <NA>   NaN         NaN
# 2           999000              NaN         <NA>   NaN         NaN
# 3           999000              NaN         <NA>   NaN         NaN
# 4           999000              NaN         <NA>   NaN         NaN
# ...            ...              ...          ...   ...         ...
# 24529       606460       73606460.0  2.10029E+11   NaN         NaN
# 24530       606460       73606460.0  2.10029E+11   NaN         NaN
# 24531       606460       73606460.0  2.10029E+11   NaN         NaN
# 24532       606460       73606460.0  2.10029E+11   NaN         NaN
# 24533       606460       73606460.0  2.10029E+11   NaN         NaN
#
#       School Type                         Demographic Suppressed Dropout Rate
# 0             NaN                        All Students          N          1.3
# 1             NaN                              Female          N          1.1
# 2             NaN                                Male          N          1.5
# 3             NaN                    African American          N          2.2
# 4             NaN    American Indian or Alaska Native          N          2.2
# ...           ...                                 ...        ...          ...
# 24529          B1  Student without Disabilities (IEP)          N            0
# 24530          B1                     English Learner          Y            *
# 24531          B1                 Non English Learner          N            0
# 24532          B1                            Homeless        NaN
# 24533          B1                             Migrant        NaN
#
# [24534 rows x 16 columns]

# %% [markdown]
# ## Data Cleanup

# %%
#### Functions
def asterisk_conversion(df, column_name):
    asterisk_convert_df = df.copy()
    asterisk_convert_df[column_name] = asterisk_convert_df[column_name].replace('*', pd.NA)
    asterisk_convert_df[column_name] = pd.to_numeric(asterisk_convert_df[column_name],  errors='coerce')
    return asterisk_convert_df

# %%
regions_df = regions_df[['NAME', 'REGION']]
regions_df = regions_df.rename(columns={'NAME': 'county_name', 'REGION': 'region'}).drop_duplicates()

regions_df
# Out:
#     county_name                region
# 0         ADAIR  SOUTH CENTRAL REGION
# 1         ALLEN  SOUTH CENTRAL REGION
# 2      ANDERSON      BLUEGRASS REGION
# 3       BALLARD        WESTERN REGION
# 4        BARREN  SOUTH CENTRAL REGION
# ..          ...                   ...
# 115       WAYNE  SOUTH CENTRAL REGION
# 116     WEBSTER        WESTERN REGION
# 117     WHITLEY           EAST REGION
# 118       WOLFE           EAST REGION
# 119    WOODFORD      BLUEGRASS REGION
#
# [120 rows x 2 columns]

# %%
enrollment_df = enrollment_df.rename(columns={
    'School Year': 'school_year',
    'County Number': 'county_number',
    'County Name': 'county_name',
    'District Number': 'district_number',
    'District Name': 'district_name',
    'School Number': 'school_number',
    'School Name': 'school_name',
    'School Code': 'school_code',
    'State School Id': 'state_school_id',
    'NCES ID': 'nces_id',
    'CO-OP': 'co_op',
    'CO-OP Code': 'co_op_code',
    'School Type': 'school_type',
    'Demographic': 'demographic',
    'All Grades': 'all_grades',
    'Preschool': 'grade_preschool',
    'K': 'grade_k',
    'Grade 1': 'grade_1',
    'Grade 2': 'grade_2',
    'Grade 3': 'grade_3',
    'Grade 4': 'grade_4',
    'Grade 5': 'grade_5',
    'Grade 6': 'grade_6',
    'Grade 7': 'grade_7',
    'Grade 8': 'grade_8',
    'Grade 9': 'grade_9',
    'Grade 10': 'grade_10',
    'Grade 11': 'grade_11',
    'Grade 12': 'grade_12',
    'Grade 14': 'grade_14'
}).drop_duplicates()



enrollment_df.head()
# Out:
#    school_year  county_number county_name  district_number  district_name  \
# 0     20232024            NaN         NaN              999  All Districts
# 1     20232024            NaN         NaN              999  All Districts
# 2     20232024            NaN         NaN              999  All Districts
# 3     20232024            NaN         NaN              999  All Districts
# 4     20232024            NaN         NaN              999  All Districts
#
#    school_number  school_name  school_code  state_school_id nces_id  ...  \
# 0            NaN  All Schools       999000              NaN    <NA>  ...
# 1            NaN  All Schools       999000              NaN    <NA>  ...
# 2            NaN  All Schools       999000              NaN    <NA>  ...
# 3            NaN  All Schools       999000              NaN    <NA>  ...
# 4            NaN  All Schools       999000              NaN    <NA>  ...
#
#   grade_4  grade_5 grade_6 grade_7 grade_8 grade_9 grade_10 grade_11 grade_12  \
# 0  49,321   49,728  46,144  49,278  50,090  56,075   54,149   50,192   47,786
# 1  23,912   24,119  22,146  23,926  24,063  27,061   26,353   24,607   23,210
# 2  25,409   25,609  23,998  25,352  26,027  29,014   27,796   25,585   24,576
# 3   5,279    5,381   4,763   5,474   5,541   6,605    6,294    5,566    5,059
# 4      84       68      59      59      72      79       66       78       68
#
#   grade_14
# 0    653.0
# 1    217.0
# 2    436.0
# 3    103.0
# 4      0.0
#
# [5 rows x 30 columns]

# %%
chronic_absenteeism_df = chronic_absenteeism_df.rename(columns={
    'School Year': 'school_year',
    'County Number': 'county_number',
    'County Name': 'county_name',
    'District Number': 'district_number',
    'District Name': 'district_name',
    'School Number': 'school_number',
    'School Name': 'school_name',
    'School Code': 'school_code',
    'State School Id': 'state_school_id',
    'NCES ID': 'nces_id',
    'CO-OP': 'co_op',
    'CO-OP Code': 'co_op_code',
    'School Type': 'school_type',
    'Grade': 'grade_level',
    'Demographic': 'demographic',
    'Suppressed': 'suppressed',
    'Chronically Absent Students': 'chronically_absent_students',
    'Students Enrolled 10 or More Days': 'enrolled_10_plus_days',
    'Chronic Absenteeism Rate': 'chronic_absenteeism_rate'
}).drop_duplicates()



# asterisk_conversion
chronic_absenteeism_df = asterisk_conversion(chronic_absenteeism_df, 'chronically_absent_students')
chronic_absenteeism_df = asterisk_conversion(chronic_absenteeism_df, 'enrolled_10_plus_days')
chronic_absenteeism_df = asterisk_conversion(chronic_absenteeism_df, 'chronic_absenteeism_rate')

# %%
dropout_rate_df = dropout_rate_df.rename(columns={
    'School Year': 'school_year',
    'County Number': 'county_number',
    'County Name': 'county_name',
    'District Number': 'district_number',
    'District Name': 'district_name',
    'School Number': 'school_number',
    'School Name': 'school_name',
    'School Code': 'school_code',
    'State School Id': 'state_school_id',
    'NCES ID': 'nces_id',
    'CO-OP': 'co_op',
    'CO-OP Code': 'co_op_code',
    'School Type': 'school_type',
    'Demographic': 'demographic',
    'Suppressed': 'suppressed',
    'Dropout Rate': 'dropout_rate',
}).drop_duplicates()


dropout_rate_df = asterisk_conversion(dropout_rate_df, 'dropout_rate')

dropout_rate_df.head(100)
# Out:
#     school_year  county_number county_name  district_number  district_name  \
# 0      20232024            NaN         NaN              999  All Districts
# 1      20232024            NaN         NaN              999  All Districts
# 2      20232024            NaN         NaN              999  All Districts
# 3      20232024            NaN         NaN              999  All Districts
# 4      20232024            NaN         NaN              999  All Districts
# ..          ...            ...         ...              ...            ...
# 95     20232024            2.0       ALLEN                5   Allen County
# 96     20232024            2.0       ALLEN                5   Allen County
# 97     20232024            2.0       ALLEN                5   Allen County
# 98     20232024            2.0       ALLEN                5   Allen County
# 99     20232024            2.0       ALLEN                5   Allen County
#
#     school_number                    school_name  school_code  \
# 0             NaN                    All Schools       999000
# 1             NaN                    All Schools       999000
# 2             NaN                    All Schools       999000
# 3             NaN                    All Schools       999000
# 4             NaN                    All Schools       999000
# ..            ...                            ...          ...
# 95           15.0  James E Bazzell Middle School         5015
# 96           15.0  James E Bazzell Middle School         5015
# 97           15.0  James E Bazzell Middle School         5015
# 98           15.0  James E Bazzell Middle School         5015
# 99           15.0  James E Bazzell Middle School         5015
#
#     state_school_id      nces_id  co_op  co_op_code school_type  \
# 0               NaN         <NA>    NaN         NaN         NaN
# 1               NaN         <NA>    NaN         NaN         NaN
# 2               NaN         <NA>    NaN         NaN         NaN
# 3               NaN         <NA>    NaN         NaN         NaN
# 4               NaN         <NA>    NaN         NaN         NaN
# ..              ...          ...    ...         ...         ...
# 95        2005015.0  2.10007E+11  GRREC       902.0          A1
# 96        2005015.0  2.10007E+11  GRREC       902.0          A1
# 97        2005015.0  2.10007E+11  GRREC       902.0          A1
# 98        2005015.0  2.10007E+11  GRREC       902.0          A1
# 99        2005015.0  2.10007E+11  GRREC       902.0          A1
#
#                             demographic suppressed  dropout_rate
# 0                          All Students          N           1.3
# 1                                Female          N           1.1
# 2                                  Male          N           1.5
# 3                      African American          N           2.2
# 4      American Indian or Alaska Native          N           2.2
# ..                                  ...        ...           ...
# 95                                Asian          Y           NaN
# 96                   Hispanic or Latino          N           0.0
# 97  Native Hawaiian or Pacific Islander        NaN           NaN
# 98                    Two or More Races          N           0.0
# 99                 White (non-Hispanic)          N           0.5
#
# [100 rows x 16 columns]

# %% [markdown]
# ## SQL DB Creation

# %%
conn = sqlite3.connect('../Dataset/dbo/ky_school_systems.db')

ky_regions_df = (regions_df[['county_name', 'region']]).drop_duplicates()

ky_district_df = (enrollment_df[['district_number','district_name','county_number','county_name']]).drop_duplicates()

ky_school_df = (enrollment_df[['school_code','school_number','school_name','state_school_id','nces_id','co_op','co_op_code','school_type','district_number']]).drop_duplicates()

ky_school_year_df = (enrollment_df[['school_year', 'school_code', 'district_number', 'county_name']]).drop_duplicates()

ky_school_enrollment_df = pd.melt(
    enrollment_df,
    id_vars = ['school_year','school_code','demographic'], 
    value_vars = ['all_grades','grade_preschool', 'grade_k', 
                  'grade_1', 'grade_2', 'grade_3', 'grade_4', 'grade_5', 
                  'grade_6', 'grade_7', 'grade_8', 
                  'grade_9', 'grade_10', 'grade_11', 'grade_12', 
                  'grade_14'],
    var_name = 'grade_level',
    value_name = 'enrollment_total').drop_duplicates()

ky_school_chron_abs_df = (chronic_absenteeism_df[['school_year', 'school_code', 'demographic', 'grade_level', 'suppressed', 'chronically_absent_students', 'enrolled_10_plus_days', 'chronic_absenteeism_rate']]).drop_duplicates()

ky_school_dropout_rate_df = (dropout_rate_df[['school_year', 'school_code', 'demographic', 'suppressed', 'dropout_rate']]).drop_duplicates()

ky_regions_df.to_sql('ky_regions', conn, index=False, if_exists='replace')
ky_district_df.to_sql('ky_district', conn, index=False, if_exists='replace')
ky_school_df.to_sql('ky_school', conn, index=False, if_exists='replace')
ky_school_year_df.to_sql('ky_school_year', conn, index=False, if_exists='replace')
ky_school_enrollment_df.to_sql('ky_school_enrollment', conn, index=False, if_exists='replace')
ky_school_chron_abs_df.to_sql('ky_school_chronic_absenteeism', conn, index=False, if_exists='replace')
ky_school_dropout_rate_df.to_sql('ky_school_dropout_rate', conn, index=False, if_exists='replace')

conn.commit()

# %%
enrollment_df[
    enrollment_df["district_number"] == 880
][
    [
        "school_year",
        "district_number",
        "district_name",
        "county_number",
        "county_name",
        "school_code",
        "school_name"
    ]
].drop_duplicates()
# Out:
#        school_year  district_number  \
# 23058     20232024              880
# 23070     20232024              880
# 23080     20232024              880
# 45949     20242025              880
# 45963     20242025              880
# 45974     20242025              880
#
#                                            district_name  county_number  \
# 23058  Kentucky National Guard Youth ChalleNGe Academies           37.0
# 23070  Kentucky National Guard Youth ChalleNGe Academies           37.0
# 23080  Kentucky National Guard Youth ChalleNGe Academies           37.0
# 45949  Kentucky National Guard Youth ChalleNGe Academies           52.0
# 45963  Kentucky National Guard Youth ChalleNGe Academies           52.0
# 45974  Kentucky National Guard Youth ChalleNGe Academies           52.0
#
#       county_name  school_code                    school_name
# 23058    FRANKLIN       880000                    All Schools
# 23070    FRANKLIN       880100  Appalachian Challenge Academy
# 23080    FRANKLIN       880101    Bluegrass Challenge Academy
# 45949       HENRY       880000                    All Schools
# 45963       HENRY       880100  Appalachian Challenge Academy
# 45974       HENRY       880101    Bluegrass Challenge Academy

# %%
test1 = """SELECT
    school_code,
    COUNT(*) AS row_count,
    COUNT(DISTINCT school_name) AS name_count,
    COUNT(DISTINCT district_number) AS district_count,
    COUNT(DISTINCT nces_id) AS nces_count,
    COUNT(DISTINCT school_type) AS type_count
FROM ky_school
GROUP BY school_code
HAVING COUNT(*) > 1
ORDER BY row_count DESC;
"""
test1t = pd.read_sql(test1, conn)
test1t
# Out:
#       school_code  row_count  name_count  district_count  nces_count  \
# 0          880101          2           1               1           2
# 1          880100          2           1               1           2
# 2          606460          2           1               1           2
# 3          606450          2           1               1           2
# 4          606000          2           1               1           1
# ...           ...        ...         ...             ...         ...
# 1508         1016          2           1               1           2
# 1509         1014          2           1               1           2
# 1510         1012          2           1               1           2
# 1511         1010          2           1               1           2
# 1512         1000          2           1               1           1
#
#       type_count
# 0              1
# 1              1
# 2              1
# 3              1
# 4              0
# ...          ...
# 1508           1
# 1509           1
# 1510           1
# 1511           1
# 1512           0
#
# [1513 rows x 6 columns]

# %%
# Naming template 
# ky_regions r
# ky_district d
# ky_school s
# ky_school_year_df sy
# ky_school_enrollment se
# ky_school_chronic_absenteeism sa
# ky_school_dropout_rate sd

# joins template:
# LEFT JOIN ky_district d ON r.ky_regions = d.district_number
# LEFT JOIN ky_district d ON s.district_number = d.district_number
# LEFT JOIN ky_school_enrollment se ON s.school_code = se.school_code
# LEFT JOIN ky_school_chronic_absenteeism sa ON s.school_code = sa.school_code
# LEFT JOIN ky_school_dropout_rate sa ON s.school_code = sd.school_code

# %%
# Number of Schools in KY School Database
# Confirmed and validated in Excel

# This checks to see what schools are not in 20242025
# SELECT distinct(s.school_name)
# FROM ky_school s
# LEFT JOIN ky_school_enrollment se ON s.school_code = se.school_code
# WHERE se.school_year <> '20242025'
# GROUP BY se.school_year
# ORDER BY count (DISTINCT school_name) desc

# SELECT  distinct(se.school_year), count (DISTINCT state_school_id) as "Schools in KY Database"
# FROM ky_school_year sy
# LEFT JOIN ky_school s on s.school_code = sy.school_code
# LEFT JOIN ky_school_enrollment se ON s.school_code = se.school_code
# WHERE school_name <> 'All Schools'
# GROUP BY se.school_year
# ORDER BY count (DISTINCT school_name) desc

ky_school_total = """ 

SELECT  distinct(se.school_year), count (DISTINCT state_school_id) as "Schools in KY Database"
FROM ky_school_year sy
LEFT JOIN ky_school s ON s.school_code = sy.school_code 
LEFT JOIN ky_school_enrollment se ON s.school_code = se.school_code 
WHERE school_name <> 'All Schools'
GROUP BY se.school_year
ORDER BY count (DISTINCT school_name) desc
"""
school_total_result = pd.read_sql(ky_school_total, conn)
school_total_result
# Out:
#    school_year  Schools in KY Database
# 0     20242025                    1398
# 1     20232024                    1398

# %% [markdown]
# 20232024 - 1398 schools
# 20242025 - 1398 schools

# %%
ky_region_school_total = """
SELECT sy.school_year, r.region, COUNT(DISTINCT s.state_school_id) AS school_count
FROM ky_school_year sy
JOIN ky_regions r ON r.county_name = sy.county_name
JOIN ky_school s ON s.school_code = sy.school_code
WHERE s.school_name <> 'All Schools'
GROUP BY sy.school_year, r.region
ORDER BY sy.school_year, school_count DESC;

"""
ky_region_school_result = pd.read_sql(ky_region_school_total, conn)
ky_region_school_result
# Out:
#     school_year                     region  school_count
# 0      20232024       SOUTH CENTRAL REGION           265
# 1      20232024  GREATER LOUISVILLE REGION           240
# 2      20232024           BLUEGRASS REGION           233
# 3      20232024             WESTERN REGION           216
# 4      20232024                EAST REGION           209
# 5      20232024   NORTHERN KENTUCKY REGION           122
# 6      20232024           NORTHEAST REGION           113
# 7      20242025       SOUTH CENTRAL REGION           266
# 8      20242025  GREATER LOUISVILLE REGION           248
# 9      20242025           BLUEGRASS REGION           227
# 10     20242025             WESTERN REGION           215
# 11     20242025                EAST REGION           208
# 12     20242025   NORTHERN KENTUCKY REGION           122
# 13     20242025           NORTHEAST REGION           112

# %%
ky_school_enroll_total = """ 

SELECT  distinct(se.school_year), sum (se.enrollment_total) as "Schools in KY Database"
FROM ky_school_year sy
LEFT JOIN ky_school s on s.school_code = sy.school_code
LEFT JOIN ky_school_enrollment se ON s.school_code = se.school_code
WHERE school_name <> 'All Schools'
GROUP BY se.school_year
ORDER BY count (DISTINCT school_name) desc
"""
school_enroll_total_result = pd.read_sql(ky_school_enroll_total, conn)
school_enroll_total_result
# Out:
#    school_year  Schools in KY Database
# 0     20242025              11703728.0
# 1     20232024              11764119.0
