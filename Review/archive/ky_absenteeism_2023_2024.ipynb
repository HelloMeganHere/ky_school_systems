# %% [markdown]
# # Kentucky School Initial Data Review
#
# The goal for this project is to see if there is a correlation between absenteeism and dropout rate. I've decided first to look at the absenteeism data from 2024-2025 and then I will continue on and look at the dropout rate.

# %% [markdown]
# Libraries and Parameters

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

seaborn.set_theme(style='whitegrid')

# %% [markdown]
# ## Chronic Absenteeism Dataset (2024-2025)

# %%
absent_2324_df = pd.read_csv("../Dataset/KYRC24_CRDC_Chronic_Absenteeism.csv")

# %% [markdown]
# ## Initial Dataset Review

# %%
absent_2324_df
# Out:
#       School Year Collected School Year  County Number County Name  \
# 0        20232024             2020-2021              1       ADAIR
# 1        20232024             2020-2021              1       ADAIR
# 2        20232024             2020-2021              1       ADAIR
# 3        20232024             2020-2021              1       ADAIR
# 4        20232024             2020-2021              1       ADAIR
# ...           ...                   ...            ...         ...
# 7538     20232024             2020-2021             11       BOYLE
# 7539     20232024             2020-2021             11       BOYLE
# 7540     20232024             2020-2021             11       BOYLE
# 7541     20232024             2020-2021             11       BOYLE
# 7542     20232024             2020-2021             11       BOYLE
#
#       District Number                 District Name  School Number  \
# 0                   1                  Adair County             10
# 1                   1                  Adair County             10
# 2                   1                  Adair County             10
# 3                   1                  Adair County             10
# 4                   1                  Adair County             10
# ...               ...                           ...            ...
# 7538              603  Kentucky School for the Deaf            390
# 7539              603  Kentucky School for the Deaf            390
# 7540              603  Kentucky School for the Deaf            390
# 7541              603  Kentucky School for the Deaf            390
# 7542              603  Kentucky School for the Deaf            390
#
#                        School Name  School Code  State School Id  \
# 0         Adair County High School         1010          1001010
# 1         Adair County High School         1010          1001010
# 2         Adair County High School         1010          1001010
# 3         Adair County High School         1010          1001010
# 4         Adair County High School         1010          1001010
# ...                            ...          ...              ...
# 7538  Kentucky School for the Deaf       603390         11603390
# 7539  Kentucky School for the Deaf       603390         11603390
# 7540  Kentucky School for the Deaf       603390         11603390
# 7541  Kentucky School for the Deaf       603390         11603390
# 7542  Kentucky School for the Deaf       603390         11603390
#
#            NCES ID  CO-OP  CO-OP Code School Type  \
# 0     210003000001  GRREC         902          A1
# 1     210003000001  GRREC         902          A1
# 2     210003000001  GRREC         902          A1
# 3     210003000001  GRREC         902          A1
# 4     210003000001  GRREC         902          A1
# ...            ...    ...         ...         ...
# 7538  210009501715   CKEC         901          D1
# 7539  210009501715   CKEC         901          D1
# 7540  210009501715   CKEC         901          D1
# 7541  210009501715   CKEC         901          D1
# 7542  210009501715   CKEC         901          D1
#
#                            Demographic  Total  Female   Male
# 0                  Total Student Count    783   349.0  434.0
# 1                     African American     11     6.0    5.0
# 2     American Indian or Alaska Native      3     1.0    2.0
# 3                                Asian      1     NaN    1.0
# 4                   Hispanic or Latino     40    14.0   26.0
# ...                                ...    ...     ...    ...
# 7538                Hispanic or Latino      6     1.0    5.0
# 7539                 Two or More Races      3     1.0    2.0
# 7540              White (non-Hispanic)     59    25.0   34.0
# 7541  Students with Disabilities (IEP)      7     3.0    4.0
# 7542                   English Learner      2     NaN    2.0
#
# [7543 rows x 18 columns]

# %% [markdown]
# ## Analyzing the Data

# %%
absent_2324_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7543 entries, 0 to 7542
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   School Year            7543 non-null   int64
#  1   Collected School Year  7543 non-null   object
#  2   County Number          7543 non-null   int64
#  3   County Name            7543 non-null   object
#  4   District Number        7543 non-null   int64
#  5   District Name          7543 non-null   object
#  6   School Number          7543 non-null   int64
#  7   School Name            7543 non-null   object
#  8   School Code            7543 non-null   int64
#  9   State School Id        7543 non-null   int64
#  10  NCES ID                7543 non-null   int64
#  11  CO-OP                  7543 non-null   object
#  12  CO-OP Code             7543 non-null   int64
#  13  School Type            7543 non-null   object
#  14  Demographic            7543 non-null   object
#  15  Total                  7543 non-null   int64
#  16  Female                 6505 non-null   float64
#  17  Male                   6814 non-null   float64
# dtypes: float64(2), int64(9), object(7)
# memory usage: 1.0+ MB

# %%
absent_2324_df.columns = absent_2324_df.columns.str.strip()

# %% [markdown]
# ## Data Cleanup

# %%
school_df = absent_2324_df[absent_2324_df["Demographic"] != "Total Student Count"]
school_df.sort_values(by="Total",ascending=False).head(10)
# Out:
#       School Year Collected School Year  County Number County Name  \
# 500      20232024             2020-2021              8       BOONE
# 6026     20232024             2020-2021             93      OLDHAM
# 3145     20232024             2020-2021             51   HENDERSON
# 3863     20232024             2020-2021             56   JEFFERSON
# 2732     20232024             2020-2021             43     GRAYSON
# 4161     20232024             2020-2021             56   JEFFERSON
# 409      20232024             2020-2021              8       BOONE
# 4105     20232024             2020-2021             56   JEFFERSON
# 5135     20232024             2020-2021             71       LOGAN
# 3677     20232024             2020-2021             56   JEFFERSON
#
#       District Number     District Name  School Number  \
# 500                35      Boone County             71
# 6026              465     Oldham County             60
# 3145              251  Henderson County             60
# 3863              275  Jefferson County            105
# 2732              211    Grayson County             85
# 4161              275  Jefferson County            200
# 409                35      Boone County             15
# 4105              275  Jefferson County            179
# 5135              351      Logan County            140
# 3677              275  Jefferson County             75
#
#                              School Name  School Code  State School Id  \
# 500            Larry A. Ryle High School        35071          8035071
# 6026           Oldham County High School       465060         93465060
# 3145        Henderson County High School       251060         51251060
# 3863                        Ballard High       275105         56275105
# 2732          Grayson County High School       211085         43211085
# 4161                  duPont Manual High       275200         56275200
# 409        Randall K. Cooper High School        35015          8035015
# 4105  Central High Magnet Career Academy       275179         56275179
# 5135            Logan County High School       351140         71351140
# 3677            Pleasure Ridge Park High       275075         56275075
#
#            NCES ID  CO-OP  CO-OP Code School Type           Demographic  \
# 500   210051000011  NKCES         905          A1  White (non-Hispanic)
# 6026  210453001125   OVEC         906          A1  White (non-Hispanic)
# 3145  210271000577   WKEC         908          A1  White (non-Hispanic)
# 3863  210299000695   GREC         909          A1  White (non-Hispanic)
# 2732  210230000486  GRREC         902          A1  White (non-Hispanic)
# 4161  210299000734   GREC         909          A1  White (non-Hispanic)
# 409   210051002206  NKCES         905          A1  White (non-Hispanic)
# 4105  210299000730   GREC         909          A1      African American
# 5135  210354001458  GRREC         902          A1  White (non-Hispanic)
# 3677  210299000668   GREC         909          A1  White (non-Hispanic)
#
#       Total  Female   Male
# 500    1388   659.0  729.0
# 6026   1288   609.0  679.0
# 3145   1215   557.0  658.0
# 3863   1062   560.0  502.0
# 2732   1057   463.0  594.0
# 4161   1041   593.0  448.0
# 409     976   450.0  526.0
# 4105    931   660.0  271.0
# 5135    917   459.0  458.0
# 3677    893   432.0  461.0

# %% [markdown]
# Removing Total Student Count to avoid skewing the dataset

# %%
gender_school_df = school_df[['Female', 'Male']].sum()
gender_school_df
# Out:
# Female    117221.0
# Male      134317.0
# dtype: float64

# %%
school_df.isna().sum()

sorted_school_df = school_df.sort_values(by="Total", ascending=False)

# %%
county_large_df = sorted_school_df.groupby("County Name")["Total"].sum().sort_values(ascending=False).head(10) 
county_large_df
# Out:
# County Name
# JEFFERSON    74165
# FAYETTE      17277
# BOONE         8632
# WARREN        7742
# DAVIESS       7045
# OLDHAM        6175
# KENTON        6011
# HENDERSON     4407
# BELL          3678
# PULASKI       3338
# Name: Total, dtype: int64

# %% [markdown]
# ## Visual Analysis and Discovery
