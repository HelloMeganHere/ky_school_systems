# %% [markdown]
# # Kentucky School Initial Data Review
#
# The goal for this project is to see if there is a correlation between absenteeism and dropout rate. I've decided first to look at the absenteeism data from 2024-2025 and then I will continue on and look at the dropout rate.

# %% [markdown]
# Libraries and Parameters

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

seaborn.set_theme(style='whitegrid')

# %% [markdown]
# ## Chronic Absenteeism Dataset (2024-2025)

# %%
absenteeism_df = pd.read_csv("../Dataset/KYRC24_OVW_Chronic_Absenteeism.csv")

# %% [markdown]
# ## Initial Dataset Review

# %%
absenteeism_df
# Out:
#         School Year  County Number County Name  District Number  \
# 0          20232024            NaN         NaN              999
# 1          20232024            NaN         NaN              999
# 2          20232024            NaN         NaN              999
# 3          20232024            NaN         NaN              999
# 4          20232024            NaN         NaN              999
# ...             ...            ...         ...              ...
# 109831     20232024           73.0     MADISON              606
# 109832     20232024           73.0     MADISON              606
# 109833     20232024           73.0     MADISON              606
# 109834     20232024           73.0     MADISON              606
# 109835     20232024           73.0     MADISON              606
#
#                           District Name  School Number        School Name  \
# 0                         All Districts            NaN        All Schools
# 1                         All Districts            NaN        All Schools
# 2                         All Districts            NaN        All Schools
# 3                         All Districts            NaN        All Schools
# 4                         All Districts            NaN        All Schools
# ...                                 ...            ...                ...
# 109831  Model Laboratory Schools at EKU          460.0  Model High School
# 109832  Model Laboratory Schools at EKU          460.0  Model High School
# 109833  Model Laboratory Schools at EKU          460.0  Model High School
# 109834  Model Laboratory Schools at EKU          460.0  Model High School
# 109835  Model Laboratory Schools at EKU          460.0  Model High School
#
#         School Code  State School Id       NCES ID CO-OP  CO-OP Code  \
# 0            999000              NaN           NaN   NaN         NaN
# 1            999000              NaN           NaN   NaN         NaN
# 2            999000              NaN           NaN   NaN         NaN
# 3            999000              NaN           NaN   NaN         NaN
# 4            999000              NaN           NaN   NaN         NaN
# ...             ...              ...           ...   ...         ...
# 109831       606460       73606460.0  2.100290e+11   NaN         NaN
# 109832       606460       73606460.0  2.100290e+11   NaN         NaN
# 109833       606460       73606460.0  2.100290e+11   NaN         NaN
# 109834       606460       73606460.0  2.100290e+11   NaN         NaN
# 109835       606460       73606460.0  2.100290e+11   NaN         NaN
#
#        School Type       Grade                       Demographic Suppressed  \
# 0              NaN  All Grades                      All Students         No
# 1              NaN  All Grades                            Female         No
# 2              NaN  All Grades                              Male         No
# 3              NaN  All Grades                  African American         No
# 4              NaN  All Grades  American Indian or Alaska Native         No
# ...            ...         ...                               ...        ...
# 109831          B1        12th                      All Students         No
# 109832          B1        12th                            Female         No
# 109833          B1        12th                              Male         No
# 109834          B1        12th              White (non-Hispanic)         No
# 109835          B1        12th               Gifted and Talented        Yes
#
#        Chronically Absent Students Students Enrolled 10 or More Days  \
# 0                          186,415                           664,910
# 1                           91,571                           321,064
# 2                           94,844                           343,846
# 3                           25,283                            73,438
# 4                              290                               962
# ...                            ...                               ...
# 109831                          10                               351
# 109832                           6                               158
# 109833                           4                               193
# 109834                          10                               304
# 109835                           *                                 *
#
#        Chronic Absenteeism Rate
# 0                            28
# 1                          28.5
# 2                          27.6
# 3                          34.4
# 4                          30.1
# ...                         ...
# 109831                      2.8
# 109832                      3.8
# 109833                      2.1
# 109834                      3.3
# 109835                        *
#
# [109836 rows x 19 columns]

# %% [markdown]
# ## Analyzing the Data

# %%
absenteeism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109836 entries, 0 to 109835
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   School Year                        109836 non-null  int64
#  1   County Number                      109583 non-null  float64
#  2   County Name                        109583 non-null  object
#  3   District Number                    109836 non-null  int64
#  4   District Name                      109836 non-null  object
#  5   School Number                      82208 non-null   float64
#  6   School Name                        109836 non-null  object
#  7   School Code                        109836 non-null  int64
#  8   State School Id                    82208 non-null   float64
#  9   NCES ID                            82208 non-null   float64
#  10  CO-OP                              109374 non-null  object
#  11  CO-OP Code                         109374 non-null  float64
#  12  School Type                        82208 non-null   object
#  13  Grade                              109836 non-null  object
#  14  Demographic                        109836 non-null  object
#  15  Suppressed                         109836 non-null  object
#  16  Chronically Absent Students        109836 non-null  object
#  17  Students Enrolled 10 or More Days  109836 non-null  object
#  18  Chronic Absenteeism Rate           109836 non-null  object
# dtypes: float64(5), int64(3), object(11)
# memory usage: 15.9+ MB

# %%
absenteeism_df.columns = absenteeism_df.columns.str.strip()

# %%
absenteeism_df.isnull().sum()
# Out:
# School Year                              0
# County Number                          253
# County Name                            253
# District Number                          0
# District Name                            0
# School Number                        27628
# School Name                              0
# School Code                              0
# State School Id                      27628
# NCES ID                              27628
# CO-OP                                  462
# CO-OP Code                             462
# School Type                          27628
# Grade                                    0
# Demographic                              0
# Suppressed                               0
# Chronically Absent Students              0
# Students Enrolled 10 or More Days        0
# Chronic Absenteeism Rate                 0
# dtype: int64

# %%
absenteeism_df.isna().sum()
# Out:
# School Year                              0
# County Number                          253
# County Name                            253
# District Number                          0
# District Name                            0
# School Number                        27628
# School Name                              0
# School Code                              0
# State School Id                      27628
# NCES ID                              27628
# CO-OP                                  462
# CO-OP Code                             462
# School Type                          27628
# Grade                                    0
# Demographic                              0
# Suppressed                               0
# Chronically Absent Students              0
# Students Enrolled 10 or More Days        0
# Chronic Absenteeism Rate                 0
# dtype: int64

# %% [markdown]
# Research why Female/Male have missing values

# %%
absenteeism_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
absenteeism_df.groupby('School Name')['Total'].agg(["mean", "min", "max"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 absenteeism_df.groupby('School Name')['Total'].agg(["mean", "min", "max"])
#
# File c:\Users\megan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File c:\Users\megan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Total'

# %%
absenteeism_df.groupby('District Name')['Total'].sum().sort_values(ascending=False)
# Out:
# District Name
# Jefferson County                 139230
# Fayette County                    31814
# Boone County                      16219
# Warren County                     12949
# Oldham County                     12164
#                                   ...
# Kentucky School for the Blind        65
# Robertson County                     58
# Augusta Independent                  52
# East Bernstadt Independent           52
# Anchorage Independent                20
# Name: Total, Length: 172, dtype: int64

# %% [markdown]
# ## Data Cleanup

# %%
school_df = absenteeism_df[absenteeism_df["Demographic"] != "Total Student Count"]
school_df.sort_values(by="Total",ascending=False).head(10)
# Out:
#       School Year  Collected School Year  County Number County Name  \
# 500      20242025               20202021              8       BOONE
# 6013     20242025               20202021             93      OLDHAM
# 3138     20242025               20202021             51   HENDERSON
# 3856     20242025               20202021             56   JEFFERSON
# 2725     20242025               20202021             43     GRAYSON
# 4154     20242025               20202021             56   JEFFERSON
# 409      20242025               20202021              8       BOONE
# 4098     20242025               20202021             56   JEFFERSON
# 5126     20242025               20202021             71       LOGAN
# 3670     20242025               20202021             56   JEFFERSON
#
#       District Number     District Name  School Number  \
# 500                35      Boone County             71
# 6013              465     Oldham County             60
# 3138              251  Henderson County             60
# 3856              275  Jefferson County            105
# 2725              211    Grayson County             85
# 4154              275  Jefferson County            200
# 409                35      Boone County             15
# 4098              275  Jefferson County            179
# 5126              351      Logan County            140
# 3670              275  Jefferson County             75
#
#                              School Name  School Code  State School Id  \
# 500            Larry A. Ryle High School        35071          8035071
# 6013           Oldham County High School       465060         93465060
# 3138        Henderson County High School       251060         51251060
# 3856                        Ballard High       275105         56275105
# 2725          Grayson County High School       211085         43211085
# 4154                  duPont Manual High       275200         56275200
# 409        Randall K. Cooper High School        35015          8035015
# 4098  Central High Magnet Career Academy       275179         56275179
# 5126            Logan County High School       351140         71351140
# 3670            Pleasure Ridge Park High       275075         56275075
#
#            NCES ID  CO-OP  CO-OP Code School Type           Demographic  \
# 500   210051000000  NKCES       905.0          A1  White (non-Hispanic)
# 6013  210453000000   OVEC       906.0          A1  White (non-Hispanic)
# 3138  210271000000   WKEC       908.0          A1  White (non-Hispanic)
# 3856  210299000000   GREC       909.0          A1  White (non-Hispanic)
# 2725  210230000000  GRREC       902.0          A1  White (non-Hispanic)
# 4154  210299000000   GREC       909.0          A1  White (non-Hispanic)
# 409   210051000000  NKCES       905.0          A1  White (non-Hispanic)
# 4098  210299000000   GREC       909.0          A1      African American
# 5126  210354000000  GRREC       902.0          A1  White (non-Hispanic)
# 3670  210299000000   GREC       909.0          A1  White (non-Hispanic)
#
#       Total  Female   Male
# 500    1388   659.0  729.0
# 6013   1288   609.0  679.0
# 3138   1215   557.0  658.0
# 3856   1062   560.0  502.0
# 2725   1057   463.0  594.0
# 4154   1041   593.0  448.0
# 409     976   450.0  526.0
# 4098    931   660.0  271.0
# 5126    917   459.0  458.0
# 3670    893   432.0  461.0

# %% [markdown]
# Removing Total Student Count to avoid skewing the dataset

# %%
gender_school_df = school_df[['Female', 'Male']].sum()
gender_school_df
# Out:
# Female    117080.0
# Male      134118.0
# dtype: float64

# %%
school_df.isna().sum()

sorted_school_df = school_df.sort_values(by="Total", ascending=False)

# %%
county_large_df = sorted_school_df.groupby("County Name")["Total"].sum().sort_values(ascending=False).head(10) 
county_large_df
# Out:
# County Name
# JEFFERSON    74165
# FAYETTE      17277
# BOONE         8632
# WARREN        7742
# DAVIESS       7045
# OLDHAM        6175
# KENTON        6011
# HENDERSON     4407
# BELL          3678
# PULASKI       3338
# Name: Total, dtype: int64

# %% [markdown]
# ## Visual Analysis and Discovery

# %%
plt.figure(figsize=(8,6))

plt.barh(county_large_df.index, county_large_df.values, color="#000066")

ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(0.5)
    spine.set_alpha(0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


plt.show()

# %% [markdown]
# Jefferson County has the highest absenteeism total in this view. I'll need to bring in enrollment rate to get %s and see how it compares this way. This may help to shed some light on the large delta.
#
# Bring in older datasets, is the absentee count flat, or trending up/down?

# %% [markdown]
# # Visualizations and Analysis

# %%
plt.figure(figsize=(8,8))

plt.pie(
    gender_school_df,
    labels=gender_school_df.index,
    startangle=125,
    colors=[ "#EDB200", "#31a17f"],
    autopct=lambda g: '{:.0f}'.format(g * gender_school_df.sum()/100)
)

plt.title("Male/Female Absenteeism Count")

plt.legend(
    labels = gender_school_df.index,
    loc="upper left",
    # title = "Platform"
)

plt.show()

# %% [markdown]
# For 2024/2025, male absentee counts appear to be slightly higher than female counts

# %%
plt.figure(figsize=(10,7))

school_df["Total"].hist(bins=8, grid=False, color="#000066")

plt.title("Absenteeism Totals")
plt.xlabel("Total")
plt.ylabel("Frequency")

plt.xticks(rotation=45, ha="right")

ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(0.5)
    spine.set_alpha(0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.spines['bottom'].set_visible(False)

plt.show()

# %% [markdown]
# Most counties are within the lower absenteeism ranges with a few exceptions in the higher end.

# %% [markdown]
# ## Key Findings for Absenteeism Dataset (2024/2025)
# => Jefferson County has the highest number of absenteeism total in this dataset.
#
# => Most counties have fairly low number of absentieeism totals.
#
# => Male Absenteeism counts are slightly higher Female Absenteeism counts.
#
# => Enrollment data will need to be brought in for further review
#
# I'll need to look at historical data and enrollment data for a more holistic view of what is going on with this data, before I to jump to conclusions...

# %% [markdown]
# ## What I've learned!
#
# It's important to keep my Markdown language area organized and clean. It can be easy for me to get lost in the lack of organization with these notebooks.
#
# Just because counts may be higher for one group over another doesn't necessarily mean this is an accurate depiction of what the data is telling me. Some counties will have higher enrollment data than others. Jefferson County is a great example of this. It's a heavily populated county and this can make it appear that it has higher % of absenteeism than other counties.
